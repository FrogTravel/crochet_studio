# %%
import os
import base64
from google import genai

# Use your API key or ensure it's in your environment variables
client = genai.Client(api_key="AIzaSyA0YTitmcNeoyRKCXw98LULyzMqoyeQI-U")

def generate_free_gemini_image(prompt, filename="free_output.png"):
    try:
        # gemini-2.5-flash-image is the ONLY model with 500 free RPD in 2026
        response = client.models.generate_content(
            model="gemini-3.1-flash-image-preview",
            contents=prompt
        )

        # Extract the image from the multimodal response
        for part in response.candidates[0].content.parts:
            if part.inline_data:
                # Part.as_image() handles the conversion to a PIL object
                img = part.as_image()
                img.save(filename)
                print(f"Success! Image saved as {filename}")
                return

        print("No image data returned. Check if the prompt was flagged by safety filters.")

    except Exception as e:
        if "429" in str(e):
            print("Rate limit hit! Even on the free tier, there is a limit of 10 requests per minute.")
        else:
            print(f"Error: {e}")

generate_free_gemini_image("A high-resolution, technical crochet stitch diagram (scheme) on a clean white background. The image features professional black line art showing intricate crochet symbols: chains (ovals), double crochets (T-shapes with slashes), and slip stitches (dots). The layout is a perfectly symmetrical circular mandala pattern, showing clear stitch intersections and structural details. Minimalist aesthetic, sharp vector-like lines, no text, no hands, no 3D yarn—only the 2D schematic symbols. Professional craft book style, 8k resolution, top-down flat lay view")
# Out:
# Success! Image saved as free_output.png
